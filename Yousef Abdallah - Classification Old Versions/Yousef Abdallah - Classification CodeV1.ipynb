# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('C:/Users/abdal/Desktop/Winter 2022/BMEN 415/Project/Classification/Classification_Diabetes_Dataset.csv')

##TRAINING: INDEX 0 to 500
##TESTING: INDEX 501 to 767
### Outcome = 1 means patient has diabetes
### Outcome = 0 means patient does not have diabetes
df = pd.DataFrame(data)
train = df.iloc[0:501,0:9]
test = df.iloc[501:768,0:9]
print(data.head())
train.corr()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.188374       0.122182      -0.067403
# Glucose                      0.188374  1.000000       0.111725       0.023405
# BloodPressure                0.122182  0.111725       1.000000       0.199686
# SkinThickness               -0.067403  0.023405       0.199686       1.000000
# Insulin                     -0.048774  0.340905       0.085775       0.453330
# BMI                          0.043810  0.236909       0.251530       0.388061
# DiabetesPedigreeFunction    -0.039948  0.162966       0.004405       0.165585
# Age                          0.529107  0.315653       0.206410      -0.135233
# Outcome                      0.220803  0.445066       0.036130       0.053922
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.048774  0.043810                 -0.039948
# Glucose                   0.340905  0.236909                  0.162966
# BloodPressure             0.085775  0.251530                  0.004405
# SkinThickness             0.453330  0.388061                  0.165585
# Insulin                   1.000000  0.210592                  0.207876
# BMI                       0.210592  1.000000                  0.128228
# DiabetesPedigreeFunction  0.207876  0.128228                  1.000000
# Age                      -0.004826  0.046869                  0.043521
# Outcome                   0.137969  0.309559                  0.178331
#
#                                Age   Outcome
# Pregnancies               0.529107  0.220803
# Glucose                   0.315653  0.445066
# BloodPressure             0.206410  0.036130
# SkinThickness            -0.135233  0.053922
# Insulin                  -0.004826  0.137969
# BMI                       0.046869  0.309559
# DiabetesPedigreeFunction  0.043521  0.178331
# Age                       1.000000  0.207754
# Outcome                   0.207754  1.000000

# %%
### Quadratic Discriminant Analysis

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis




#acc = accuracy_score(y_test,y_predict_test)   #Accuracy for classification

# %%
### Hist Gradient Boosting

# %%
### Stochastic Gradient Descent
